# %%
#####################################################################
#              Download pdf's from SSPC                             #
#                                                                   #
#      Source: http://www.informeseguridad.cns.gob.mx/              #
#                                                                   #
#     Column name: "Homicidios dolosos Fuentes abiertas"            #
#                                                                   #
#           Author: Mariana Fernandez                               #
#         contact: mariana.fernadez@cide.edu                        #
# Date:17/08/2020                                                   #
#####################################################################

# %%
# Libraries

import urllib
from datetime import date, timedelta
import datetime

# %%
def download_pdfs_sspc(dirname):
    """ 
    download_pdfs_sspc. 
  
    Download pdfs required for posterior scraping 
  
    Parameters: 
    dirname (str)     : Directory where the new data sets will be save
      

    """
    ## Ask for start date and end date (Range of dates that you want to download)
    date_entry = input('Enter a date in YYYY-MM-DD format (start date): ')
    year, month, day = map(int, date_entry.split('-'))
    start_date = datetime.date(year, month, day)

    date_entry = input('Enter a date in YYYY-MM-DD format (end date): ')
    year, month, day = map(int, date_entry.split('-'))
    end_date = datetime.date(year, month, day)
    
    
    # Create a range of dates 
    v_dates = []
    
    #start_date = date()
    #end_date = date(end_date)

    #end_date = yesterday
    #end_date = end_date

    delta = timedelta(days=1)
    while start_date <= end_date:
        print(start_date.strftime("%d%m%Y"))
        v_dates.append(start_date.strftime("%d%m%Y"))
        start_date += delta
        
        
    for i in (v_dates):
        url = "http://www.informeseguridad.cns.gob.mx/files/homicidios_" + i + ".pdf"
        path = dirname
        try:
            data = urllib.request.urlretrieve(url, path + i + ".pdf")
            print(url)
        except:
            print("Error, cannot read url")
            print(url)

# %%
download_pdfs_sspc("/Users/marianafernandez/Documents/PADeCI/homicides-mx-data/data_download/data_source/fuentes_abiertas/")
# Out:
# Enter a date in YYYY-MM-DD format (start date): 2020-12-01
# Enter a date in YYYY-MM-DD format (end date): 2020-12-31
# 01122020
# 02122020
# 03122020
# 04122020
# 05122020
# 06122020
# 07122020
# 08122020
# 09122020
# 10122020
# 11122020
# 12122020
# 13122020
# 14122020
# 15122020
# 16122020
# 17122020
# 18122020
# 19122020
# 20122020
# 21122020
# 22122020
# 23122020
# 24122020
# 25122020
# 26122020
# 27122020
# 28122020
# 29122020
# 30122020
# 31122020
# http://www.informeseguridad.cns.gob.mx/files/homicidios_01122020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_02122020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_03122020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_04122020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_05122020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_06122020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_07122020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_08122020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_09122020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_10122020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_11122020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_12122020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_13122020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_14122020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_15122020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_16122020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_17122020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_18122020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_19122020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_20122020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_21122020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_22122020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_23122020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_24122020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_25122020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_26122020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_27122020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_28122020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_29122020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_30122020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_31122020.pdf
