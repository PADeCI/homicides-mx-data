# %%
#####################################################################
#              Download pdf's from SSPC                             #
#                                                                   #
#      Source: http://www.informeseguridad.cns.gob.mx/              #
#                                                                   #
#     Column name: "Homicidios dolosos Fuentes abiertas"            #
#                                                                   #
#           Author: Mariana Fernandez                               #
#         contact: mariana.fernadez@cide.edu                        #
# Date:17/08/2020                                                   #
#####################################################################

# %%
# Libraries

import urllib
from datetime import date, timedelta
import datetime

# %%
def download_pdfs_sspc(dirname):
    """ 
    download_pdfs_sspc. 
  
    Download pdfs required for posterior scraping 
  
    Parameters: 
    dirname (str)     : Directory where the new data sets will be save
      

    """
    ## Ask for start date and end date (Range of dates that you want to download)
    date_entry = input('Enter a date in YYYY-MM-DD format (start date): ')
    year, month, day = map(int, date_entry.split('-'))
    start_date = datetime.date(year, month, day)

    date_entry = input('Enter a date in YYYY-MM-DD format (end date): ')
    year, month, day = map(int, date_entry.split('-'))
    end_date = datetime.date(year, month, day)
    
    
    # Create a range of dates 
    v_dates = []
    
    #start_date = date()
    #end_date = date(end_date)

    #end_date = yesterday
    #end_date = end_date

    delta = timedelta(days=1)
    while start_date <= end_date:
        print(start_date.strftime("%d%m%Y"))
        v_dates.append(start_date.strftime("%d%m%Y"))
        start_date += delta
        
        
    for i in (v_dates):
        url = "http://www.informeseguridad.cns.gob.mx/files/homicidios_" + i + ".pdf"
        path = dirname
        try:
            data = urllib.request.urlretrieve(url, path + i + ".pdf")
            print(url)
        except:
            print("Error, cannot read url")
            print(url)

# %%
#download_pdfs_sspc("/Users/marianafernandez/Documents/PADeCI/homicides-mx-data/data_download/data_source/")
download_pdfs_sspc("/Users/marianafernandez/Documents/PADeCI/homicides-mx-data/Anomalias/")
# Out:
# Enter a date in YYYY-MM-DD format (start date): 2020-02-01
# Enter a date in YYYY-MM-DD format (end date): 2020-02-29
# 01022020
# 02022020
# 03022020
# 04022020
# 05022020
# 06022020
# 07022020
# 08022020
# 09022020
# 10022020
# 11022020
# 12022020
# 13022020
# 14022020
# 15022020
# 16022020
# 17022020
# 18022020
# 19022020
# 20022020
# 21022020
# 22022020
# 23022020
# 24022020
# 25022020
# 26022020
# 27022020
# 28022020
# 29022020
# http://www.informeseguridad.cns.gob.mx/files/homicidios_01022020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_02022020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_03022020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_04022020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_05022020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_06022020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_07022020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_08022020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_09022020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_10022020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_11022020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_12022020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_13022020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_14022020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_15022020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_16022020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_17022020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_18022020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_19022020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_20022020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_21022020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_22022020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_23022020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_24022020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_25022020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_26022020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_27022020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_28022020.pdf
# http://www.informeseguridad.cns.gob.mx/files/homicidios_29022020.pdf
